# %%
import pandas as pd
import numpy as np

df_raw = pd.read_csv("../data/trx-10k.csv")

#cleaning up the text entries
text_cols = ["status", "card_type", "city"]
for col in text_cols:
    df_raw[col] = df_raw[col].str.lower().str.strip().str.replace(r"[^a-z0-9 ]", "", regex=True)

#Checking what to set the cutoff at.
for col in text_cols:
    print(f"\n-- {col} --")
    print(df_raw[col].value_counts())

#Setting cutoffs
cutoffs = {
    "status":    1500,
    "card_type": 900,
    "city":      500,
}
# Out:
# -- status --
# status
# success    4415
# fail       4185
# failed     1181
# succeed     219
# Name: count, dtype: int64
#
# -- card_type --
# card_type
# visa           2744
# mastercard     2040
# discover       1647
# amex           1263
# mastcard       1000
# vsa             801
# master card     194
# Name: count, dtype: int64
#
# -- city --
# city
# tehran     2658
# tabriz     1368
# isfahan    1073
# karaj      1037
# mashhad     900
# shiraz      727
# qom         669
# ahvaz       632
# thr         409
# tehrn       332
# thran        79
# Name: count, dtype: int64

# %%
#Cleaning up TEXT data based on cutoffs
for col, cutoff in cutoffs.items():
    counts = df_raw[col].value_counts()
    valid = counts[counts >= cutoff].index
    df_raw[col] = df_raw[col].where(df_raw[col].isin(valid))

df_clean = df_raw.dropna().reset_index(drop=True)
df_clean = df_clean[df_clean["amount"] > 0].reset_index(drop=True)

#Cleaning up date data by converting to a datetime
df_clean["time"] = pd.to_datetime(df_clean["time"], errors="coerce")
df_clean = df_clean.dropna().reset_index(drop=True)

#Printing cleaned TEXT data (time and date still need to be cleaned)
for col in df_clean:
    print(f"\n-- {col} --")
    print(df_clean[col])
# Out:
# -- status --
# 0       success
# 1       success
# 2          fail
# 3       success
# 4          fail
#          ...
# 5305       fail
# 5306    success
# 5307    success
# 5308    success
# 5309    success
# Name: status, Length: 5310, dtype: str
#
# -- time --
# 0      2025-09-07 10:48:00
# 1      2025-09-20 13:10:00
# 2      2025-09-29 03:27:00
# 3      2025-09-11 11:11:00
# 4      2025-09-08 21:21:00
#                ...
# 5305   2025-09-23 09:45:00
# 5306   2025-09-06 07:32:00
# 5307   2025-09-05 21:23:00
# 5308   2025-09-24 10:48:00
# 5309   2025-09-21 07:08:00
# Name: time, Length: 5310, dtype: datetime64[us]
#
# -- card_type --
# 0             visa
# 1         mastcard
# 2             visa
# 3             visa
# 4         discover
#            ...
# 5305          amex
# 5306      mastcard
# 5307      discover
# 5308    mastercard
# 5309      discover
# Name: card_type, Length: 5310, dtype: str
#
# -- city --
# 0       tehran
# 1       tehran
# 2       tehran
# 3       tehran
# 4       tehran
#          ...
# 5305     karaj
# 5306     karaj
# 5307    tabriz
# 5308    tehran
# 5309    tehran
# Name: city, Length: 5310, dtype: str
#
# -- amount --
# 0       1427657.0
# 1       1578078.0
# 2        250000.0
# 3       1782689.0
# 4       1050805.0
#           ...
# 5305    1578078.0
# 5306       5000.0
# 5307       1000.0
# 5308     585954.0
# 5309    1463119.0
# Name: amount, Length: 5310, dtype: float64
#
# -- id --
# 0       98
# 1       52
# 2       20
# 3       59
# 4       77
#         ..
# 5305     1
# 5306     7
# 5307    67
# 5308    53
# 5309    91
# Name: id, Length: 5310, dtype: int64
